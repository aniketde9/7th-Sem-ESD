# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.10.7)
# Requirement already satisfied: requests>=2.18.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from chembl_webresource_client) (2.26.0)
# Requirement already satisfied: requests-cache~=0.7.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: easydict in /srv/conda/envs/notebook/lib/python3.7/site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from chembl_webresource_client) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: pyyaml>=5.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: attrs<22.0,>=21.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 19.4 MB/s
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 40.8 MB/s            MB 40.8 MB/s eta 0:00:01��██████████████▌  | 14.5 MB 40.8 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.21.5 pandas-1.3.5

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('aromatase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P11511', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'P22443', 'xref_name': None, 'xre...  Rattus norvegicus
#
#               pref_name  score  species_group_flag target_chembl_id  \
# 0  Cytochrome P450 19A1   20.0               False       CHEMBL1978
# 1  Cytochrome P450 19A1   20.0               False       CHEMBL3859
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P11511', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'P22443', 'component_descriptio...  SINGLE PROTEIN   10116

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1978'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        82585                  []    CHEMBL666794
# 1             None        94540                  []    CHEMBL666794
# 2             None       112960                  []    CHEMBL661700
#
#                                    assay_description assay_type  \
# 0                 Inhibition of Cytochrome P450 19A1          B
# 1                 Inhibition of Cytochrome P450 19A1          B
# 2  In vitro inhibition of human Cytochrome P450 19A1          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Cytochrome P450 19A1          9606       None  None
# 1  ...    Homo sapiens  Cytochrome P450 19A1          9606       None  None
# 2  ...    Homo sapiens  Cytochrome P450 19A1          9606       None  None
#
#    type  units    uo_units upper_value  value
# 0  IC50     uM  UO_0000065        None    7.1
# 1  IC50     uM  UO_0000065        None   50.0
# 2  IC50     uM  UO_0000065        None  0.238
#
# [3 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)
